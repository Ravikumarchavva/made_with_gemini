# %%
from sqlalchemy import create_engine, text

def get_db_connection():
    # Replace with your actual database connection string
    connection_string = "postgresql://postgres:postgres@localhost/postgres"
    engine = create_engine(connection_string)
    return engine.connect()     

def execute_query(query):
    connection = get_db_connection()
    try:
        result = connection.execute(text(query))
        return result.fetchall()
    finally:
        connection.close()

execute_query("SELECT * FROM public.testgg;")  # Replace with your actual query
# Out:
# [(1, 'User_1', 'user1@example.com', 20, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (2, 'User_2', 'user2@example.com', 37, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (3, 'User_3', 'user3@example.com', 54, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (4, 'User_4', 'user4@example.com', 41, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (5, 'User_5', 'user5@example.com', 41, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (6, 'User_6', 'user6@example.com', 23, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (7, 'User_7', 'user7@example.com', 31, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (8, 'User_8', 'user8@example.com', 57, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (9, 'User_9', 'user9@example.com', 51, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (10, 'User_10', 'user10@example.com', 29, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (11, 'User_11', 'user11@example.com', 33, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (12, 'User_12', 'user12@example.com', 39, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (13, 'User_13', 'user13@example.com', 47, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (14, 'User_14', 'user14@example.com', 29, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (15, 'User_15', 'user15@example.com', 32, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (16, 'User_16', 'user16@example.com', 41, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (17, 'User_17', 'user17@example.com', 47, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (18, 'User_18', 'user18@example.com', 29, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (19, 'User_19', 'user19@example.com', 31, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (20, 'User_20', 'user20@example.com', 49, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (21, 'User_21', 'user21@example.com', 51, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (22, 'User_22', 'user22@example.com', 56, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (23, 'User_23', 'user23@example.com', 40, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (24, 'User_24', 'user24@example.com', 27, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (25, 'User_25', 'user25@example.com', 57, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (26, 'User_26', 'user26@example.com', 56, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (27, 'User_27', 'user27@example.com', 41, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (28, 'User_28', 'user28@example.com', 28, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (29, 'User_29', 'user29@example.com', 43, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343)),
#  (30, 'User_30', 'user30@example.com', 47, datetime.datetime(2025, 7, 12, 1, 41, 14, 135343))]
